# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Conv1D, Dense, Bidirectional, LSTM, Dropout, BatchNormalization, MaxPooling1D, Add, Concatenate
from tensorflow.keras.models import Model

SIGNAL_WINDOW_SIZE = 100
SAVE_PREFIX = '_ultra'

# Load the data you saved
print("Loading data...")
X_train = np.load(f'X_train{SAVE_PREFIX}.npy')
y_train = np.load(f'y_train{SAVE_PREFIX}.npy')
X_test = np.load(f'X_test{SAVE_PREFIX}.npy')
y_test = np.load(f'y_test{SAVE_PREFIX}.npy')

# Reshape
X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)
print(f"Data loaded. X_train shape: {X_train.shape}")
# Out:
# Loading data...
# Data loaded. X_train shape: (8000, 100, 1)

# %%
print("Defining Improved (Smarter Hybrid CNN+LSTM) model...")

signal_input = Input(shape=(SIGNAL_WINDOW_SIZE, 1), name='signal_input')

# Block 1: Double CNN Feature Extractor (The Improvement)
x = Conv1D(filters=64, kernel_size=5, activation='relu', padding='same')(signal_input)
x = BatchNormalization()(x)
x = Conv1D(filters=128, kernel_size=3, activation='relu', padding='same')(x) 
x = BatchNormalization()(x)
x = MaxPooling1D(pool_size=2)(x) 

# Block 2: Stronger LSTM Sequence Reader
x = Bidirectional(LSTM(48))(x) 

# Block 3: Classification Head
x = Dropout(0.4)(x) 
x = Dense(64, activation='relu')(x)
output = Dense(1, activation='sigmoid')(x) 

model_improved = Model(inputs=signal_input, outputs=output)

# Use the standard, reliable 'adam' optimizer
model_improved.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

model_improved.summary()
# Out:
# Defining Improved (Smarter Hybrid CNN+LSTM) model...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ signal_input (InputLayer)       │ (None, 100, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 100, 64)        │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 100, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 100, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 100, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 50, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 96)             │        67,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,097 (391.00 KB)
#  Trainable params: 99,713 (389.50 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
# Train for 50 epochs as recommended for difficult data
history_improved = model_improved.fit(
    X_train, 
    y_train, 
    validation_split=0.2,
    epochs=50, 
    batch_size=32
)

# Save the model
model_improved.save(f'improved_model.keras')

# Evaluate
results_improved = model_improved.evaluate(X_test, y_test)
print(f"Test AUC: {results_improved[2]}")
# Out:
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.5263 - auc: 0.5485 - loss: 0.6948 - val_accuracy: 0.5094 - val_auc: 0.5401 - val_loss: 0.6984
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5442 - auc: 0.5660 - loss: 0.6871 - val_accuracy: 0.5481 - val_auc: 0.5746 - val_loss: 0.6806
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5962 - auc: 0.6442 - loss: 0.6550 - val_accuracy: 0.5606 - val_auc: 0.6144 - val_loss: 0.6719
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7495 - auc: 0.8291 - loss: 0.5077 - val_accuracy: 0.9137 - val_auc: 0.9646 - val_loss: 0.2455
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9211 - auc: 0.9629 - loss: 0.2275 - val_accuracy: 0.9694 - val_auc: 0.9879 - val_loss: 0.1173
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9619 - auc: 0.9852 - loss: 0.1260 - val_accuracy: 0.9706 - val_auc: 0.9893 - val_loss: 0.1048
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9677 - auc: 0.9923 - loss: 0.0961 - val_accuracy: 0.9581 - val_auc: 0.9938 - val_loss: 0.1177
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9748 - auc: 0.9942 - loss: 0.0803 - val_accuracy: 0.9706 - val_auc: 0.9879 - val_loss: 0.1062
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9725 - auc: 0.9921 - loss: 0.0881 - val_accuracy: 0.9794 - val_auc: 0.9952 - val_loss: 0.0658
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9808 - auc: 0.9955 - loss: 0.0655 - val_accuracy: 0.9706 - val_auc: 0.9942 - val_loss: 0.0864
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9784 - auc: 0.9961 - loss: 0.0649 - val_accuracy: 0.9831 - val_auc: 0.9961 - val_loss: 0.0627
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9837 - auc: 0.9976 - loss: 0.0481 - val_accuracy: 0.9725 - val_auc: 0.9906 - val_loss: 0.0992
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9852 - auc: 0.9980 - loss: 0.0440 - val_accuracy: 0.9844 - val_auc: 0.9954 - val_loss: 0.0627
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9836 - auc: 0.9973 - loss: 0.0487 - val_accuracy: 0.9837 - val_auc: 0.9965 - val_loss: 0.0585
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9897 - auc: 0.9991 - loss: 0.0304 - val_accuracy: 0.9794 - val_auc: 0.9951 - val_loss: 0.0674
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9867 - auc: 0.9983 - loss: 0.0375 - val_accuracy: 0.9831 - val_auc: 0.9978 - val_loss: 0.0541
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9891 - auc: 0.9985 - loss: 0.0319 - val_accuracy: 0.9887 - val_auc: 0.9984 - val_loss: 0.0406
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9903 - auc: 0.9988 - loss: 0.0309 - val_accuracy: 0.9831 - val_auc: 0.9928 - val_loss: 0.0697
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9925 - auc: 0.9994 - loss: 0.0236 - val_accuracy: 0.9769 - val_auc: 0.9899 - val_loss: 0.1039
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9892 - auc: 0.9994 - loss: 0.0289 - val_accuracy: 0.9819 - val_auc: 0.9960 - val_loss: 0.0584
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9873 - auc: 0.9989 - loss: 0.0341 - val_accuracy: 0.9819 - val_auc: 0.9944 - val_loss: 0.0656
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9891 - auc: 0.9984 - loss: 0.0316 - val_accuracy: 0.9787 - val_auc: 0.9960 - val_loss: 0.0667
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9936 - auc: 0.9996 - loss: 0.0199 - val_accuracy: 0.9906 - val_auc: 0.9971 - val_loss: 0.0466
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9933 - auc: 0.9992 - loss: 0.0228 - val_accuracy: 0.9881 - val_auc: 0.9963 - val_loss: 0.0439
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9958 - auc: 0.9999 - loss: 0.0127 - val_accuracy: 0.9794 - val_auc: 0.9918 - val_loss: 0.0944
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9945 - auc: 0.9998 - loss: 0.0172 - val_accuracy: 0.9819 - val_auc: 0.9924 - val_loss: 0.0780
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9977 - auc: 0.9998 - loss: 0.0096 - val_accuracy: 0.9850 - val_auc: 0.9963 - val_loss: 0.0621
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9917 - auc: 0.9995 - loss: 0.0225 - val_accuracy: 0.9869 - val_auc: 0.9945 - val_loss: 0.0602
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9919 - auc: 0.9988 - loss: 0.0285 - val_accuracy: 0.9881 - val_auc: 0.9963 - val_loss: 0.0504
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9933 - auc: 0.9994 - loss: 0.0199 - val_accuracy: 0.9856 - val_auc: 0.9950 - val_loss: 0.0699
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9958 - auc: 0.9998 - loss: 0.0093 - val_accuracy: 0.9856 - val_auc: 0.9953 - val_loss: 0.0646
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9906 - auc: 0.9987 - loss: 0.0317 - val_accuracy: 0.9850 - val_auc: 0.9954 - val_loss: 0.0579
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9912 - auc: 0.9993 - loss: 0.0238 - val_accuracy: 0.9837 - val_auc: 0.9969 - val_loss: 0.0592
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9955 - auc: 0.9999 - loss: 0.0115 - val_accuracy: 0.9875 - val_auc: 0.9964 - val_loss: 0.0523
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9973 - auc: 0.9996 - loss: 0.0093 - val_accuracy: 0.9875 - val_auc: 0.9947 - val_loss: 0.0628
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9927 - auc: 0.9989 - loss: 0.0227 - val_accuracy: 0.9819 - val_auc: 0.9968 - val_loss: 0.0578
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9950 - auc: 0.9994 - loss: 0.0163 - val_accuracy: 0.9862 - val_auc: 0.9950 - val_loss: 0.0588
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9969 - auc: 0.9998 - loss: 0.0101 - val_accuracy: 0.9862 - val_auc: 0.9941 - val_loss: 0.0695
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9944 - auc: 0.9991 - loss: 0.0174 - val_accuracy: 0.9844 - val_auc: 0.9954 - val_loss: 0.0666
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9953 - auc: 0.9997 - loss: 0.0146 - val_accuracy: 0.9850 - val_auc: 0.9957 - val_loss: 0.0614
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9973 - auc: 1.0000 - loss: 0.0080 - val_accuracy: 0.9869 - val_auc: 0.9952 - val_loss: 0.0620
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9952 - auc: 0.9996 - loss: 0.0124 - val_accuracy: 0.9869 - val_auc: 0.9958 - val_loss: 0.0571
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9937 - auc: 0.9995 - loss: 0.0175 - val_accuracy: 0.9856 - val_auc: 0.9965 - val_loss: 0.0550
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9969 - auc: 0.9998 - loss: 0.0107 - val_accuracy: 0.9844 - val_auc: 0.9944 - val_loss: 0.0721
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9941 - auc: 0.9997 - loss: 0.0177 - val_accuracy: 0.9794 - val_auc: 0.9941 - val_loss: 0.0742
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9961 - auc: 0.9996 - loss: 0.0123 - val_accuracy: 0.9875 - val_auc: 0.9972 - val_loss: 0.0547
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9966 - auc: 0.9996 - loss: 0.0103 - val_accuracy: 0.9812 - val_auc: 0.9945 - val_loss: 0.0753
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9952 - auc: 0.9996 - loss: 0.0153 - val_accuracy: 0.9681 - val_auc: 0.9864 - val_loss: 0.1596
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9919 - auc: 0.9994 - loss: 0.0236 - val_accuracy: 0.9869 - val_auc: 0.9970 - val_loss: 0.0420
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9983 - auc: 1.0000 - loss: 0.0049 - val_accuracy: 0.9887 - val_auc: 0.9965 - val_loss: 0.0551
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9855 - auc: 0.9926 - loss: 0.0773
# Test AUC: 0.9925733804702759

# %%
print("Evaluating improved model on the test set...")
results_improved = model_improved.evaluate(X_test, y_test)

print(f"Test Loss: {results_improved[0]}")
print(f"Test Accuracy: {results_improved[1]}")
print(f"Test AUC: {results_improved[2]}")
# Out:
# Evaluating improved model on the test set...
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9855 - auc: 0.9926 - loss: 0.0773
# Test Loss: 0.07727358490228653
# Test Accuracy: 0.9854999780654907
# Test AUC: 0.9925733804702759
