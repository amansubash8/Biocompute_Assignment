# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, Bidirectional, LSTM, Dense, Concatenate, Flatten
from tensorflow.keras.models import Model

# --- !! This MUST match the number from Day 2 !! ---
SIGNAL_WINDOW_SIZE = 100
# --------------------------------------------------

# Load the data you saved
print("Loading data...")
X_train = np.load('X_train_ultra.npy')
y_train = np.load('y_train_ultra.npy')
X_test = np.load('X_test_ultra.npy')
y_test = np.load('y_test_ultra.npy')

# --- CRITICAL STEP: Reshaping ---
# Keras 1D CNNs expect a 3D shape: (samples, steps, channels)
# Your data is (samples, steps). We must add a "channels" dimension of 1.
X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)

print(f"Data loaded. X_train shape (after reshape): {X_train.shape}")
# Out:
# Loading data...
# Data loaded. X_train shape (after reshape): (8000, 100, 1)

# %%
print("Defining Baseline (DeepSignal-like) model...")

# --- Module 1: CNN for raw signals ---
signal_input = Input(shape=(SIGNAL_WINDOW_SIZE, 1), name='signal_input')
cnn_features = Conv1D(filters=64, kernel_size=5, activation='relu')(signal_input)
cnn_features = Flatten()(cnn_features)

# --- Module 2: Bi-LSTM for sequence context ---
# The paper's architecture is complex. This is a simplified version
# that captures the *spirit* (CNN + RNN).
bilstm_features = Bidirectional(LSTM(32))(signal_input)

# --- Concatenate and Classify ---
combined_features = Concatenate()([cnn_features, bilstm_features])

dense_layer = Dense(64, activation='relu')(combined_features)
output = Dense(1, activation='sigmoid')(dense_layer) # Binary classification (0 or 1)

model_baseline = Model(inputs=signal_input, outputs=output)

# Compile the model
model_baseline.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

model_baseline.summary()
# Out:
# Defining Baseline (DeepSignal-like) model...
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ signal_input        │ (None, 100, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 96, 64)    │        384 │ signal_input[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 6144)      │          0 │ conv1d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_2     │ (None, 64)        │      8,704 │ signal_input[0][… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 6208)      │          0 │ flatten_2[0][0],  │
# │ (Concatenate)       │                   │            │ bidirectional_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │    397,376 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1)         │         65 │ dense_4[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 406,529 (1.55 MB)
#  Trainable params: 406,529 (1.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("Training baseline model...")

# We train on a small number of epochs.
# The assignment says a "toy example is acceptable".
# This proves the *methodology*[cite: 39].
history_baseline = model_baseline.fit(
    X_train, 
    y_train, 
    validation_split=0.2, # Use 20% of training data for validation
    epochs=50, 
    batch_size=32
)

print("\nBaseline model training complete.")

# Save the trained model
model_baseline.save('baseline_model.keras')
print("Baseline model saved to 'baseline_model.keras'")
# Out:
# Training baseline model...
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.5964 - auc: 0.6306 - loss: 0.6669 - val_accuracy: 0.6625 - val_auc: 0.7283 - val_loss: 0.6226
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6980 - auc: 0.7636 - loss: 0.5839 - val_accuracy: 0.7275 - val_auc: 0.8146 - val_loss: 0.5345
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.7767 - auc: 0.8545 - loss: 0.4858 - val_accuracy: 0.7906 - val_auc: 0.8817 - val_loss: 0.4495
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.8533 - auc: 0.9267 - loss: 0.3662 - val_accuracy: 0.8575 - val_auc: 0.9290 - val_loss: 0.3524
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9084 - auc: 0.9658 - loss: 0.2613 - val_accuracy: 0.8881 - val_auc: 0.9547 - val_loss: 0.2859
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9370 - auc: 0.9839 - loss: 0.1880 - val_accuracy: 0.9000 - val_auc: 0.9685 - val_loss: 0.2411
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9544 - auc: 0.9908 - loss: 0.1405 - val_accuracy: 0.9200 - val_auc: 0.9714 - val_loss: 0.2205
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9644 - auc: 0.9951 - loss: 0.1097 - val_accuracy: 0.9256 - val_auc: 0.9743 - val_loss: 0.2033
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9770 - auc: 0.9974 - loss: 0.0851 - val_accuracy: 0.9231 - val_auc: 0.9737 - val_loss: 0.2097
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9836 - auc: 0.9984 - loss: 0.0670 - val_accuracy: 0.9256 - val_auc: 0.9732 - val_loss: 0.2122
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9902 - auc: 0.9994 - loss: 0.0479 - val_accuracy: 0.9175 - val_auc: 0.9711 - val_loss: 0.2295
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9875 - auc: 0.9994 - loss: 0.0467 - val_accuracy: 0.9156 - val_auc: 0.9723 - val_loss: 0.2305
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9930 - auc: 0.9997 - loss: 0.0352 - val_accuracy: 0.9200 - val_auc: 0.9739 - val_loss: 0.2246
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9961 - auc: 1.0000 - loss: 0.0241 - val_accuracy: 0.9294 - val_auc: 0.9721 - val_loss: 0.2320
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9972 - auc: 1.0000 - loss: 0.0200 - val_accuracy: 0.9262 - val_auc: 0.9722 - val_loss: 0.2399
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9987 - auc: 1.0000 - loss: 0.0134 - val_accuracy: 0.9219 - val_auc: 0.9731 - val_loss: 0.2471
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9989 - auc: 1.0000 - loss: 0.0120 - val_accuracy: 0.9231 - val_auc: 0.9717 - val_loss: 0.2560
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9998 - auc: 1.0000 - loss: 0.0074 - val_accuracy: 0.9206 - val_auc: 0.9720 - val_loss: 0.2650
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.9998 - auc: 1.0000 - loss: 0.0050 - val_accuracy: 0.9200 - val_auc: 0.9690 - val_loss: 0.2769
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0044 - val_accuracy: 0.9206 - val_auc: 0.9698 - val_loss: 0.2911
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0034 - val_accuracy: 0.9156 - val_auc: 0.9682 - val_loss: 0.2917
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0033 - val_accuracy: 0.9206 - val_auc: 0.9686 - val_loss: 0.2872
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0021 - val_accuracy: 0.9212 - val_auc: 0.9654 - val_loss: 0.3101
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0018 - val_accuracy: 0.9206 - val_auc: 0.9658 - val_loss: 0.3120
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0015 - val_accuracy: 0.9212 - val_auc: 0.9683 - val_loss: 0.3109
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0012 - val_accuracy: 0.9187 - val_auc: 0.9641 - val_loss: 0.3210
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0010 - val_accuracy: 0.9175 - val_auc: 0.9650 - val_loss: 0.3302
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 9.3839e-04 - val_accuracy: 0.9169 - val_auc: 0.9646 - val_loss: 0.3315
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 7.8768e-04 - val_accuracy: 0.9162 - val_auc: 0.9632 - val_loss: 0.3530
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 6.6021e-04 - val_accuracy: 0.9175 - val_auc: 0.9632 - val_loss: 0.3438
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 5.6967e-04 - val_accuracy: 0.9175 - val_auc: 0.9631 - val_loss: 0.3598
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 5.2352e-04 - val_accuracy: 0.9150 - val_auc: 0.9624 - val_loss: 0.3752
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.9017e-04 - val_accuracy: 0.9169 - val_auc: 0.9603 - val_loss: 0.3775
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.2162e-04 - val_accuracy: 0.9162 - val_auc: 0.9615 - val_loss: 0.3868
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.5684e-04 - val_accuracy: 0.9175 - val_auc: 0.9617 - val_loss: 0.3821
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.9214e-04 - val_accuracy: 0.9169 - val_auc: 0.9610 - val_loss: 0.3913
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.6588e-04 - val_accuracy: 0.9137 - val_auc: 0.9586 - val_loss: 0.3954
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.2685e-04 - val_accuracy: 0.9144 - val_auc: 0.9598 - val_loss: 0.4064
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.0438e-04 - val_accuracy: 0.9162 - val_auc: 0.9600 - val_loss: 0.4191
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.7872e-04 - val_accuracy: 0.9150 - val_auc: 0.9591 - val_loss: 0.4175
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.5661e-04 - val_accuracy: 0.9162 - val_auc: 0.9576 - val_loss: 0.4310
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.4381e-04 - val_accuracy: 0.9169 - val_auc: 0.9577 - val_loss: 0.4335
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.2100e-04 - val_accuracy: 0.9125 - val_auc: 0.9576 - val_loss: 0.4429
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.0925e-04 - val_accuracy: 0.9144 - val_auc: 0.9583 - val_loss: 0.4359
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 9.7362e-05 - val_accuracy: 0.9181 - val_auc: 0.9570 - val_loss: 0.4388
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 8.3011e-05 - val_accuracy: 0.9150 - val_auc: 0.9558 - val_loss: 0.4514
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 7.4080e-05 - val_accuracy: 0.9162 - val_auc: 0.9554 - val_loss: 0.4640
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 6.4274e-05 - val_accuracy: 0.9131 - val_auc: 0.9560 - val_loss: 0.4768
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 6.0867e-05 - val_accuracy: 0.9131 - val_auc: 0.9566 - val_loss: 0.4723
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 5.4371e-05 - val_accuracy: 0.9112 - val_auc: 0.9521 - val_loss: 0.4869
#
# Baseline model training complete.
# Baseline model saved to 'baseline_model.keras'

# %%
print("Evaluating baseline model on the test set...")
results_baseline = model_baseline.evaluate(X_test, y_test)

print(f"Test Loss: {results_baseline[0]}")
print(f"Test Accuracy: {results_baseline[1]}")
print(f"Test AUC: {results_baseline[2]}")
# Out:
# Evaluating baseline model on the test set...
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9055 - auc: 0.9509 - loss: 0.5221
# Test Loss: 0.5221409797668457
# Test Accuracy: 0.9054999947547913
# Test AUC: 0.9509173631668091
